# %% [markdown]
# # ETL Processes
# Use this notebook to develop the ETL process for each of your tables before completing the `etl.py` file to load the whole datasets.

# %%
import os
import glob
import psycopg2
import pandas as pd
from sql_queries import *

# %%
conn = psycopg2.connect("host=127.0.0.1 dbname=sparkifydb user=student password=student")
cur = conn.cursor()

# %%
def get_files(filepath):
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,'*.json'))
        for f in files :
            all_files.append(os.path.abspath(f))
    
    return all_files

# %% [markdown]
# # Process `song_data`
# In this first part, you'll perform ETL on the first dataset, `song_data`, to create the `songs` and `artists` dimensional tables.
#
# Let's perform ETL on a single song file and load a single record into each table to start.
# - Use the `get_files` function provided above to get a list of all song JSON files in `data/song_data`
# - Select the first song in this list
# - Read the song file and view the data

# %%
song_files = get_files("data/song_data")

# %%
filepath = song_files[0]

# %%
### Had a crack at reading and concatenating all of the files

song_files = get_files("data/song_data")
dfs =[]
for file in song_files:
    data = pd.read_json(file, lines=True)
    dfs.append(data)
df = pd.concat(dfs, ignore_index=True)

df.head()
# Out:
#             artist_id  artist_latitude              artist_location  \
# 0  ARD7TVE1187B99BFB1              NaN              California - LA
# 1  ARNTLGG11E2835DDB9              NaN
# 2  AR8ZCNI1187B9A069B              NaN
# 3  AR10USD1187B99F3F1              NaN  Burlington, Ontario, Canada
# 4  ARMJAGH1187FB546F3         35.14968                  Memphis, TN
#
#    artist_longitude            artist_name   duration  num_songs  \
# 0               NaN                 Casual  218.93179          1
# 1               NaN                    Clp  266.39628          1
# 2               NaN       Planet P Project  269.81832          1
# 3               NaN  Tweeterfriendly Music  189.57016          1
# 4         -90.04892           The Box Tops  148.03546          1
#
#               song_id                              title  year
# 0  SOMZWCG12A8C13C480                   I Didn't Mean To     0
# 1  SOUDSGM12AC9618304  Insatiable (Instrumental Version)     0
# 2  SOIAZJW12AB01853F1                         Pink World  1984
# 3  SOHKNRJ12A6701D1F8                       Drop of Rain     0
# 4  SOCIWDW12A8C13D406                          Soul Deep  1969

# %%
df = pd.read_json(filepath, lines=True)
df.head()
# Out:
#             artist_id  artist_latitude  artist_location  artist_longitude  \
# 0  ARD7TVE1187B99BFB1              NaN  California - LA               NaN
#
#   artist_name   duration  num_songs             song_id             title  \
# 0      Casual  218.93179          1  SOMZWCG12A8C13C480  I Didn't Mean To
#
#    year
# 0     0

# %% [markdown]
# ## #1: `songs` Table
# #### Extract Data for Songs Table
# - Select columns for song ID, title, artist ID, year, and duration
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `song_data`

# %%
song_data = df[['song_id','title','artist_id','year','duration']].values.tolist()
song_data[0]
# Out:
# ['SOMZWCG12A8C13C480', "I Didn't Mean To", 'ARD7TVE1187B99BFB1', 0, 218.93179]

# %% [markdown]
# #### Insert Record into Song Table
# Implement the `song_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song into the `songs` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songs` table in the sparkify database.

# %%
cur.execute(song_table_insert, song_data)
conn.commit()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-0c375ac7939b> in <module>()
# ----> 1 cur.execute(song_table_insert, song_data)
#       2 conn.commit()
#
# IndexError: list index out of range

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# ## #2: `artists` Table
# #### Extract Data for Artists Table
# - Select columns for artist ID, name, location, latitude, and longitude
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `artist_data`

# %%
artist_data = df[['artist_id', 'artist_name', 'artist_location', 'artist_latitude', 'artist_longitude']].values.tolist()
artist_data

# %% [markdown]
# #### Insert Record into Artist Table
# Implement the `artist_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song's artist into the `artists` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `artists` table in the sparkify database.

# %%
cur.execute(artist_table_insert, artist_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# # Process `log_data`
# In this part, you'll perform ETL on the second dataset, `log_data`, to create the `time` and `users` dimensional tables, as well as the `songplays` fact table.
#
# Let's perform ETL on a single log file and load a single record into each table.
# - Use the `get_files` function provided above to get a list of all log JSON files in `data/log_data`
# - Select the first log file in this list
# - Read the log file and view the data

# %%
log_files = get_files("data/log_data")
num_files = len(log_files)
#print('{} files found in {}'.format(num_files, filepath))
    
# create log dataframe
raw_log_dfs =[]
for file in log_files:
    data = pd.read_json(file, lines=True)
    raw_log_dfs.append(data)
log_df = pd.concat(raw_log_dfs, ignore_index=True)
    
# filter by NextSong action
log_df = log_df[log_df['page']=="NextSong"]

len(log_df.index)
# Out:
# 6820

# %% [markdown]
# ## #3: `time` Table
# #### Extract Data for Time Table
# - Filter records by `NextSong` action
# - Convert the `ts` timestamp column to datetime
#   - Hint: the current timestamp is in milliseconds
# - Extract the timestamp, hour, day, week of year, month, year, and weekday from the `ts` column and set `time_data` to a list containing these values in order
#   - Hint: use pandas' [`dt` attribute](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html) to access easily datetimelike properties.
# - Specify labels for these columns and set to `column_labels`
# - Create a dataframe, `time_df,` containing the time data for this file by combining `column_labels` and `time_data` into a dictionary and converting this into a dataframe

# %%
log_df_ss = log_df[log_df['page']=="NextSong"]
log_df_ss.head()
# Out:
#           artist       auth firstName gender  itemInSession lastName  \
# 0  Stephen Lynch  Logged In    Jayden      M              0     Bell
# 1        Manowar  Logged In     Jacob      M              0    Klein
# 2      Morcheeba  Logged In     Jacob      M              1    Klein
# 3       Maroon 5  Logged In     Jacob      M              2    Klein
# 4          Train  Logged In     Jacob      M              3    Klein
#
#       length level                             location method      page  \
# 0  182.85669  free      Dallas-Fort Worth-Arlington, TX    PUT  NextSong
# 1  247.56200  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 2  257.41016  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 3  231.23546  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 4  216.76363  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
#
#    registration  sessionId                                  song  status  \
# 0  1.540992e+12        829                     Jim Henson's Dead     200
# 1  1.540558e+12       1049                           Shell Shock     200
# 2  1.540558e+12       1049  Women Lose Weight (Feat: Slick Rick)     200
# 3  1.540558e+12       1049             Won't Go Home Without You     200
# 4  1.540558e+12       1049                      Hey_ Soul Sister     200
#
#               ts                                          userAgent userId
# 0  1543537327796  Mozilla/5.0 (compatible; MSIE 10.0; Windows NT...     91
# 1  1543540121796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 2  1543540368796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 3  1543540625796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 4  1543540856796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73

# %%
#log_df_ss['ts'] = pd.to_datetime(log_df_ss['ts'], unit ='ms')
t = pd.to_datetime(log_df['ts'], unit ='ms')
t.head()
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#           artist       auth firstName gender  itemInSession lastName  \
# 0  Stephen Lynch  Logged In    Jayden      M              0     Bell
# 1        Manowar  Logged In     Jacob      M              0    Klein
# 2      Morcheeba  Logged In     Jacob      M              1    Klein
# 3       Maroon 5  Logged In     Jacob      M              2    Klein
# 4          Train  Logged In     Jacob      M              3    Klein
#
#       length level                             location method      page  \
# 0  182.85669  free      Dallas-Fort Worth-Arlington, TX    PUT  NextSong
# 1  247.56200  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 2  257.41016  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 3  231.23546  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 4  216.76363  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
#
#    registration  sessionId                                  song  status  \
# 0  1.540992e+12        829                     Jim Henson's Dead     200
# 1  1.540558e+12       1049                           Shell Shock     200
# 2  1.540558e+12       1049  Women Lose Weight (Feat: Slick Rick)     200
# 3  1.540558e+12       1049             Won't Go Home Without You     200
# 4  1.540558e+12       1049                      Hey_ Soul Sister     200
#
#                        ts                                          userAgent  \
# 0 2018-11-30 00:22:07.796  Mozilla/5.0 (compatible; MSIE 10.0; Windows NT...
# 1 2018-11-30 01:08:41.796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 2 2018-11-30 01:12:48.796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 3 2018-11-30 01:17:05.796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 4 2018-11-30 01:20:56.796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
#
#   userId
# 0     91
# 1     73
# 2     73
# 3     73
# 4     73

# %%
#(start_time, hour, day, week, month, year, weekday)
time_data = [
    ('start_time', log_df_ss['ts'].dt.time), 
    ('hour', log_df_ss['ts'].dt.hour), 
    ('day', log_df_ss['ts'].dt.day), 
    ('week', log_df_ss['ts'].dt.week),
    ('month', log_df_ss['ts'].dt.month),
    ('year', log_df_ss['ts'].dt.year),
    ('weekday', log_df_ss['ts'].dt.weekday)
]
#time_data
#column_labels = ("start_time", "hour", "day", "week", "month", "year", "weekday")

# %%
time_df = pd.DataFrame.from_dict(dict(time_data))
time_df.head()
# Out:
#         start_time  hour  day  week  month  year  weekday
# 0  00:22:07.796000     0   30    48     11  2018        4
# 1  01:08:41.796000     1   30    48     11  2018        4
# 2  01:12:48.796000     1   30    48     11  2018        4
# 3  01:17:05.796000     1   30    48     11  2018        4
# 4  01:20:56.796000     1   30    48     11  2018        4

# %% [markdown]
# #### Insert Records into Time Table
# Implement the `time_table_insert` query in `sql_queries.py` and run the cell below to insert records for the timestamps in this log file into the `time` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `time` table in the sparkify database.

# %%
for i, row in time_df.iterrows():
    cur.execute(time_table_insert, list(row))
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #4: `users` Table
# #### Extract Data for Users Table
# - Select columns for user ID, first name, last name, gender and level and set to `user_df`

# %%
user_df = log_df_ss[['userId','firstName','lastName','gender','level']]
user_df.head()
# Out:
#   userId firstName lastName gender level
# 0     91    Jayden     Bell      M  free
# 1     73     Jacob    Klein      M  paid
# 2     73     Jacob    Klein      M  paid
# 3     73     Jacob    Klein      M  paid
# 4     73     Jacob    Klein      M  paid

# %% [markdown]
# #### Insert Records into Users Table
# Implement the `user_table_insert` query in `sql_queries.py` and run the cell below to insert records for the users in this log file into the `users` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `users` table in the sparkify database.

# %%
for i, row in user_df.iterrows():
    cur.execute(user_table_insert, row)
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #5: `songplays` Table
# #### Extract Data and Songplays Table
# This one is a little more complicated since information from the songs table, artists table, and original log file are all needed for the `songplays` table. Since the log file does not specify an ID for either the song or the artist, you'll need to get the song ID and artist ID by querying the songs and artists tables to find matches based on song title, artist name, and song duration time.
# - Implement the `song_select` query in `sql_queries.py` to find the song ID and artist ID based on the title, artist name, and duration of a song.
# - Select the timestamp, user ID, level, song ID, artist ID, session ID, location, and user agent and set to `songplay_data`
#
# #### Insert Records into Songplays Table
# - Implement the `songplay_table_insert` query and run the cell below to insert records for the songplay actions in this log file into the `songplays` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songplays` table in the sparkify database.

# %%
log_df_ss[log_df_ss['sessionId'] == 818].sort_values(by=['artist'])
# Out:
#                                               artist       auth firstName  \
# 4894                                    3 Doors Down  Logged In      Lily
# 4889                                             AFI  Logged In      Lily
# 5099                                   Abstract Rude  Logged In      Lily
# 4880                                        Al Green  Logged In      Lily
# 5113                                 Alliance Ethnik  Logged In      Lily
# 4883                                        Aly & AJ  Logged In      Lily
# 5115                                          Aya RL  Logged In      Lily
# 4884                                            Beck  Logged In      Lily
# 4892                                       Ben Jelen  Logged In      Lily
# 4876                                 Bertine Zetlitz  Logged In      Lily
# 5094                                 Black Eyed Peas  Logged In      Lily
# 5104                                  Bram Vermeulen  Logged In      Lily
# 4863                         Bullet For My Valentine  Logged In      Lily
# 4860                                             CSS  Logged In      Lily
# 4881                               Cage The Elephant  Logged In      Lily
# 4866                                            Cake  Logged In      Lily
# 5085                        California Swag District  Logged In      Lily
# 5095                                   Carolina Liar  Logged In      Lily
# 4877                             Christopher O'Riley  Logged In      Lily
# 5105                             Death Cab for Cutie  Logged In      Lily
# 5080                             Dee Dee Bridgewater  Logged In      Lily
# 4864                                    Deepest Blue  Logged In      Lily
# 5106                                   Dwight Yoakam  Logged In      Lily
# 4888                               ENUR Feat NATASJA  Logged In      Lily
# 4890              Edward Sharpe & The Magnetic Zeros  Logged In      Lily
# 4869                               El Canto del Loco  Logged In      Lily
# 4862                                           Elena  Logged In      Lily
# 5114                                            Enya  Logged In      Lily
# 4870                                Five Iron Frenzy  Logged In      Lily
# 4882                                    George Jones  Logged In      Lily
# ...                                              ...        ...       ...
# 4856                                        Kid Rock  Logged In      Lily
# 4868                                       LL Cool J  Logged In      Lily
# 4867                                    Lara & Reyes  Logged In      Lily
# 4865                                  Laurie Berkner  Logged In      Lily
# 5089                                      Lily Allen  Logged In      Lily
# 5098                                            Live  Logged In      Lily
# 4891                             Martina Topley Bird  Logged In      Lily
# 4887                                   Melody Gardot  Logged In      Lily
# 5086                                      Miike Snow  Logged In      Lily
# 5084                                       Nightwish  Logged In      Lily
# 5082                                         Nirvana  Logged In      Lily
# 5097                                            Onar  Logged In      Lily
# 4886                                       Rammstein  Logged In      Lily
# 4858                                  Ray LaMontagne  Logged In      Lily
# 5092                                         Rihanna  Logged In      Lily
# 5102                                      Rilo Kiley  Logged In      Lily
# 5108                                          Rosana  Logged In      Lily
# 5103                                         Shwayze  Logged In      Lily
# 5088                                           Sikth  Logged In      Lily
# 4872                              Sin Animo De Lucro  Logged In      Lily
# 4873                                          Slayer  Logged In      Lily
# 4885                                The Decemberists  Logged In      Lily
# 5112                                     The Killers  Logged In      Lily
# 4874                                       The Maine  Logged In      Lily
# 5101                      The Men They Couldn't Hang  Logged In      Lily
# 5090  The Presidents of the United States of America  Logged In      Lily
# 5081                                     Tim O'brien  Logged In      Lily
# 5093                                     Tomas Bodin  Logged In      Lily
# 5083                                          Weezer  Logged In      Lily
# 5091                                      Wordsworth  Logged In      Lily
#
#      gender  itemInSession lastName     length level  \
# 4894      F             36     Koch  237.13914  paid
# 4889      F             32     Koch  328.72444  paid
# 5099      F             57     Koch  196.85832  paid
# 4880      F             23     Koch  133.58975  paid
# 5113      F             68     Koch  195.94404  paid
# 4883      F             26     Koch  150.59546  paid
# 5115      F             70     Koch  225.43628  paid
# 4884      F             27     Koch  211.14730  paid
# 4892      F             35     Koch  226.55955  paid
# 4876      F             19     Koch  246.30812  paid
# 5094      F             52     Koch  326.86975  paid
# 5104      F             62     Koch  251.42812  paid
# 4863      F              6     Koch  258.27220  paid
# 4860      F              3     Koch  191.42485  paid
# 4881      F             24     Koch  228.02240  paid
# 4866      F              9     Koch  190.32771  paid
# 5085      F             43     Koch  239.17669  paid
# 5095      F             53     Koch  240.45669  paid
# 4877      F             20     Koch  337.91955  paid
# 5105      F             63     Koch  189.38730  paid
# 5080      F             38     Koch  318.64118  paid
# 4864      F              7     Koch  210.54649  paid
# 5106      F             64     Koch  239.30730  paid
# 4888      F             31     Koch  230.63465  paid
# 4890      F             33     Koch  306.31138  paid
# 4869      F             12     Koch  226.03710  paid
# 4862      F              5     Koch  269.58322  paid
# 5114      F             69     Koch  289.80200  paid
# 4870      F             13     Koch  236.09424  paid
# 4882      F             25     Koch  146.85995  paid
# ...     ...            ...      ...        ...   ...
# 4856      F              1     Koch  296.95955  paid
# 4868      F             11     Koch  248.68526  paid
# 4867      F             10     Koch  277.41995  paid
# 4865      F              8     Koch  132.67546  paid
# 5089      F             47     Koch  199.88853  paid
# 5098      F             56     Koch  286.98077  paid
# 4891      F             34     Koch  177.08363  paid
# 4887      F             30     Koch  261.32853  paid
# 5086      F             44     Koch  385.35791  paid
# 5084      F             42     Koch  286.19710  paid
# 5082      F             40     Koch  215.11791  paid
# 5097      F             55     Koch  306.67710  paid
# 4886      F             29     Koch  256.28689  paid
# 4858      F              2     Koch  235.15383  paid
# 5092      F             50     Koch  229.04118  paid
# 5102      F             60     Koch  234.03057  paid
# 5108      F             66     Koch  256.31302  paid
# 5103      F             61     Koch  201.63873  paid
# 5088      F             46     Koch  250.53995  paid
# 4872      F             15     Koch  212.19220  paid
# 4873      F             16     Koch  233.45587  paid
# 4885      F             28     Koch  313.65179  paid
# 5112      F             67     Koch  230.39955  paid
# 4874      F             17     Koch  209.00526  paid
# 5101      F             59     Koch  251.14077  paid
# 5090      F             48     Koch  495.77751  paid
# 5081      F             39     Koch  176.14322  paid
# 5093      F             51     Koch  396.53832  paid
# 5083      F             41     Koch  479.32036  paid
# 5091      F             49     Koch  253.15220  paid
#
#                                 location method      page  registration  \
# 4894  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 4889  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 5099  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 4880  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 5113  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 4883  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 5115  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 4884  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 4892  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 4876  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 5094  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 5104  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 4863  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 4860  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 4881  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 4866  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 5085  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 5095  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 4877  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 5105  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 5080  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 4864  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 5106  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 4888  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 4890  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 4869  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 4862  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 5114  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 4870  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 4882  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# ...                                  ...    ...       ...           ...
# 4856  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 4868  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 4867  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 4865  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 5089  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 5098  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 4891  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 4887  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 5086  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 5084  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 5082  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 5097  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 4886  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 4858  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 5092  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 5102  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 5108  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 5103  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 5088  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 4872  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 4873  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 4885  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 5112  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 4874  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 5101  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 5090  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 5081  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 5093  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 5083  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 5091  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
#
#       sessionId                                             song  status  \
# 4894        818                                 Here Without You     200
# 4889        818                                       Affliction     200
# 5099        818                                        Nuff Fire     200
# 4880        818                            I Say A Little Prayer     200
# 5113        818                         SinceritÃÂ© Et Jalousie     200
# 4883        818                                        Like Whoa     200
# 5115        818                                             Jazz     200
# 4884        818                                             Girl     200
# 4892        818                          Come On (Album Version)     200
# 4876        818                                Snow On A Hot Day     200
# 5094        818                                         My Humps     200
# 5104        818                                            Mamma     200
# 4863        818                                Her Voice Resides     200
# 4860        818                     Meeting Paris Hilton (Album)     200
# 4881        818                            Back Against The Wall     200
# 4866        818                        Jesus Wrote a Blank Check     200
# 5085        818                           Teach Me How To Dougie     200
# 5095        818     Show Me What I'm Looking For (Album Version)     200
# 4877        818                                 paranoid android     200
# 5105        818  I Will Follow You into the Dark (Album Version)     200
# 5080        818                                   La Vie En Rose     200
# 4864        818                                     Deepest Blue     200
# 5106        818                                   You're The One     200
# 4888        818                                    Calabria 2007     200
# 4890        818                                             Home     200
# 4869        818                             La Suerte De Mi Vida     200
# 4862        818                                   Setanta matins     200
# 5114        818                                      China Roses     200
# 4870        818                                           Canada     200
# 4882        818                                    She's My Rock     200
# ...         ...                                              ...     ...
# 4856        818                  All Summer Long (Album Version)     200
# 4868        818                              Around The Way Girl     200
# 4867        818                                      El Castillo     200
# 4865        818                                        The Crabs     200
# 5089        818                                         Not Fair     200
# 5098        818                                   Lakini's Juice     200
# 4891        818                                           Poison     200
# 4887        818                                  Worrisome Heart     200
# 5086        818                                           Silvia     200
# 5084        818                                    She Is My Sin     200
# 5082        818                                        Love Buzz     200
# 5097        818                                Xehasmeni Melodia     200
# 4886        818                                           MOSKAU     200
# 4858        818                                           Barfly     200
# 5092        818                                       Take A Bow     200
# 5102        818               The Absence Of God (Album Version)     200
# 5108        818                                   Si tu no estas     200
# 5103        818                                     Lost My Mind     200
# 5088        818                                        Peep Show     200
# 4872        818                                          Dime Tu     200
# 4873        818                                    Ghosts Of War     200
# 4885        818                                 Sons & Daughters     200
# 5112        818                  The Ballad of Michael Valentine     200
# 4874        818                                      You Left Me     200
# 5101        818                                      Ironmasters     200
# 5090        818                                             Lump     200
# 5081        818                           Think About Last Night     200
# 5093        818                       Back To The African Garden     200
# 5083        818                                   Only In Dreams     200
# 5091        818                Right Now (Produced by Ayatollah)     200
#
#                  ts                                          userAgent userId
# 4894  1542844428796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 4889  1542843391796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 5099  1542850491796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 4880  1542841463796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 5113  1542852842796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 4883  1542841970796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 5115  1542853326796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 4884  1542842120796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 4892  1542844202796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 4876  1542840436796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 5094  1542849131796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 5104  1542851504796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 4863  1542837676796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 4860  1542836964796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 4881  1542841596796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 4866  1542838276796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 5085  1542846506796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 5095  1542849457796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 4877  1542840682796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 5105  1542851755796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 5080  1542845032796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 4864  1542837934796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 5106  1542851944796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 4888  1542843161796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 4890  1542843719796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 4869  1542838991796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 4862  1542837407796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 5114  1542853037796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 4870  1542839217796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 4882  1542841824796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# ...             ...                                                ...    ...
# 4856  1542836433796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 4868  1542838743796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 4867  1542838466796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 4865  1542838144796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 5089  1542847559796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 5098  1542850205796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 4891  1542844025796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 4887  1542842900796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 5086  1542846745796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 5084  1542846220796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 5082  1542845526796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 5097  1542849899796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 4886  1542842644796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 4858  1542836729796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 5092  1542848506796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 5102  1542851069796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 5108  1542852356796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 5103  1542851303796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 5088  1542847309796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 4872  1542839676796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 4873  1542839888796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 4885  1542842331796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 5112  1542852612796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 4874  1542840121796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 5101  1542850818796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 5090  1542847758796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 5081  1542845350796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 5093  1542848735796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 5083  1542845741796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 5091  1542848253796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
#
# [70 rows x 18 columns]

# %%
# session_id = 818
for index, row in log_df_ss.iterrows():

    # get songid and artistid from song and artist tables
    cur.execute(song_select, (row.song, row.artist, row.length))
    results = cur.fetchone()
    print(results)
    
    if results:
        songid, artistid = results
    else:
        songid, artistid = None, None
    timestamp = log_df_ss['ts'].dt.time
    #print(row)
    # insert songplay record

    songplay_data = (index,timestamp[index], row.userId, row.level, songid, artistid, row.sessionId, row.location, row.userAgent)
    #print(songplay_data)
    #cur.execute(songplay_table_insert, songplay_data)
    #conn.commit()
    
songplay_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-897b02a5724a> in <module>()
#       1 # session_id = 818
# ----> 2 for index, row in log_df_ss.iterrows():
#       3
#       4     # get songid and artistid from song and artist tables
#       5     cur.execute(song_select, (row.song, row.artist, row.length))
#
# NameError: name 'log_df_ss' is not defined

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# # Close Connection to Sparkify Database

# %%
conn.close()

# %% [markdown]
# # Implement `etl.py`
# Use what you've completed in this notebook to implement `etl.py`.
